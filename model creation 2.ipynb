# %% [markdown]
# <a href="https://colab.research.google.com/github/isha3456/Isha-/blob/main/model%20creation%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

placement_dataset = {
    "Student_ID": [
        "S001", "S002", "S003", "S004", "S005",
        "S006", "S007", "S008", "S009", "S010"
    ],

    "CGPA": [
        9.2, 8.7, 7.5, 9.5, 8.0,
        6.8, 8.9, 7.2, 9.0, 8.3
    ],
    "Attendance": [
        95, 90, 85, 98, 88,
        75, 92, 80, 96, 89
    ],
    "Coding_Score": [
        92, 85, 70, 96, 78,
        65, 88, 72, 94, 81
    ],
    "Communication_Score": [
        88, 82, 75, 91, 80,
        68, 85, 70, 89, 78
    ],
    "Projects": [
        4, 3, 2, 5, 3,
        1, 4, 2, 5, 3
    ],
    "Internship_Score": [
        90, 80, 65, 95, 72,
        55, 84, 60, 92, 75
    ],
    "Placement_Package_LPA": [
        18.5, 14.2, 8.5, 22.0, 10.5,
        5.5, 15.8, 7.2, 19.5, 11.8
    ]
    }

df=pd.DataFrame(placement_dataset)
print(df)
x=df[['CGPA','Attendance','Coding_Score','Communication_Score','Projects','Internship_Score']]
y=df[['Placement_Package_LPA']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
a=float(input("Enter CGPA  :"))
b=float(input("Enter Attendance  :"))
c=float(input("Enter Coding Score   :"))
d=float(input("Enter Communication Score   :"))
e=float(input("Enter Projects   :"))
f=float(input("Enter Internship Score   :"))
user=[[a,b,c,d,e,f]]
prediction=model.predict(user)
print("Your future package by analyzing your performance could be:",float(prediction))
# Out:
#   Student_ID  CGPA  Attendance  Coding_Score  Communication_Score  Projects  \
# 0       S001   9.2          95            92                   88         4
# 1       S002   8.7          90            85                   82         3
# 2       S003   7.5          85            70                   75         2
# 3       S004   9.5          98            96                   91         5
# 4       S005   8.0          88            78                   80         3
# 5       S006   6.8          75            65                   68         1
# 6       S007   8.9          92            88                   85         4
# 7       S008   7.2          80            72                   70         2
# 8       S009   9.0          96            94                   89         5
# 9       S010   8.3          89            81                   78         3
#
#    Internship_Score  Placement_Package_LPA
# 0                90                   18.5
# 1                80                   14.2
# ...
