# %% [markdown]
# <a href="https://colab.research.google.com/github/isha3456/Isha-/blob/main/HW23_06_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1: Loan Approval Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error


X = [
    [25000, 550],
    [35000, 650],
    [45000, 700],
    [20000, 500],
    [50000, 750]
]

# Labels
y = [
    "Reject",
    "Approve",
    "Approve",
    "Reject",
    "Approve"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New applicant
new_applicant = [[40000, 680]]

# Predict loan status
prediction = knn.predict(new_applicant)

print("Predicted Loan Status:", prediction[0])

# Show the 3 nearest neighbors
distances, indices = knn.kneighbors(new_applicant)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Income={X[idx][0]}, "
        f"Credit Score={X[idx][1]}, Loan={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Loan Status: Approve
#
# Nearest Neighbors:
# Neighbor 1: Income=45000, Credit Score=700, Loan=Approve, Distance=5000.04
# Neighbor 2: Income=35000, Credit Score=650, Loan=Approve, Distance=5000.09
# Neighbor 3: Income=50000, Credit Score=750, Loan=Approve, Distance=10000.24

# %%
#2: Internship Selection Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

X = [
    [60, 65],
    [70, 75],
    [85, 88],
    [90, 92],
    [95, 96]
]


y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New student data
new_student = [[80, 84]]

# Predict selection status
prediction = knn.predict(new_student)

print("Predicted Internship Selection:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_student)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Project={X[idx][0]}, "
        f"Quiz={X[idx][1]}, Selected={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Internship Selection: Yes
#
# Nearest Neighbors:
# Neighbor 1: Project=85, Quiz=88, Selected=Yes, Distance=6.40
# Neighbor 2: Project=90, Quiz=92, Selected=Yes, Distance=12.81
# Neighbor 3: Project=70, Quiz=75, Selected=No, Distance=13.45

# %%
#3: Disease Prediction
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

X = [
    [110, 90],   # Patient A
    [120, 110],  # Patient B
    [140, 150],  # Patient C
    [150, 170],  # Patient D
    [160, 180]   # Patient E
]

# Labels
y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New patient data
new_patient = [[130, 130]]

# Predict disease status
prediction = knn.predict(new_patient)

print("Predicted Disease Status:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_patient)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: BP={X[idx][0]}, "
        f"Sugar={X[idx][1]}, Disease={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Disease Status: No
#
# Nearest Neighbors:
# Neighbor 1: BP=120, Sugar=110, Disease=No, Distance=22.36
# Neighbor 2: BP=140, Sugar=150, Disease=Yes, Distance=22.36
# Neighbor 3: BP=110, Sugar=90, Disease=No, Distance=44.72

# %%
# 4: Food Delivery Delay Prediction


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error


X = [
    [2, 20],
    [3, 30],
    [5, 45],
    [6, 50],
    [8, 70]
]

y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New order data
new_order = [[4, 35]]

# Predict delay status
prediction = knn.predict(new_order)

print("Predicted Delivery Delay:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_order)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Distance={X[idx][0]}, "
        f"Orders={X[idx][1]}, Delay={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Delivery Delay: No
#
# Nearest Neighbors:
# Neighbor 1: Distance=3, Orders=30, Delay=No, Distance=5.10
# Neighbor 2: Distance=5, Orders=45, Delay=Yes, Distance=10.05
# Neighbor 3: Distance=2, Orders=20, Delay=No, Distance=15.13

# %%
#5: Customer Subscription Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

X = [
    [22, 1000],  # Customer A
    [28, 3000],  # Customer B
    [35, 5000],  # Customer C
    [40, 7000],  # Customer D
    [45, 9000]   # Customer E
]

y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New customer data
new_customer = [[32, 4500]]

# Predict subscription status
prediction = knn.predict(new_customer)

print("Predicted Subscription Status:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_customer)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Age={X[idx][0]}, "
        f"Spending={X[idx][1]}, Subscribe={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Subscription Status: Yes
#
# Nearest Neighbors:
# Neighbor 1: Age=35, Spending=5000, Subscribe=Yes, Distance=500.01
# Neighbor 2: Age=28, Spending=3000, Subscribe=No, Distance=1500.01
# Neighbor 3: Age=40, Spending=7000, Subscribe=Yes, Distance=2500.01

# %%
#6: Gym Membership Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error


X = [
    [18, 1],
    [22, 2],
    [25, 4],
    [30, 5],
    [35, 6]
]


y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New person's data
new_person = [[24, 3]]

# Predict gym membership
prediction = knn.predict(new_person)

print("Predicted Gym Membership:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_person)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Age={X[idx][0]}, "
        f"Exercise Hours={X[idx][1]}, "
        f"Join Gym={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Gym Membership: No
#
# Nearest Neighbors:
# Neighbor 1: Age=25, Exercise Hours=4, Join Gym=Yes, Distance=1.41
# Neighbor 2: Age=22, Exercise Hours=2, Join Gym=No, Distance=2.24
# Neighbor 3: Age=18, Exercise Hours=1, Join Gym=No, Distance=6.32

# %%
# 7: Online Course Enrollment Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

X = [
    [40, 50],
    [55, 60],
    [70, 75],
    [85, 88],
    [92, 95]
]

y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New student data
new_student = [[72, 78]]

# Predict enrollment status
prediction = knn.predict(new_student)

print("Predicted Enrollment Status:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_student)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Programming={X[idx][0]}, "
        f"Interest={X[idx][1]}, "
        f"Enroll={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Enrollment Status: Yes
#
# Nearest Neighbors:
# Neighbor 1: Programming=70, Interest=75, Enroll=Yes, Distance=3.61
# Neighbor 2: Programming=85, Interest=88, Enroll=Yes, Distance=16.40
# Neighbor 3: Programming=55, Interest=60, Enroll=No, Distance=24.76

# %%
# 8: Electricity Consumption Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

X = [
    [2, 5],
    [3, 7],
    [4, 10],
    [5, 12],
    [6, 15]
]

y = [
    "Low",
    "Low",
    "High",
    "High",
    "High"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New house data
new_house = [[4, 9]]

# Predict electricity usage
prediction = knn.predict(new_house)

print("Predicted Electricity Usage:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_house)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Family Size={X[idx][0]}, "
        f"Appliances={X[idx][1]}, "
        f"Usage={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Electricity Usage: High
#
# Nearest Neighbors:
# Neighbor 1: Family Size=4, Appliances=10, Usage=High, Distance=1.00
# Neighbor 2: Family Size=3, Appliances=7, Usage=Low, Distance=2.24
# Neighbor 3: Family Size=5, Appliances=12, Usage=High, Distance=3.16

# %%
# 9: Product Return Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

X = [
    [1, 5],
    [2, 4],
    [4, 3],
    [5, 2],
    [7, 1]
]

y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New customer data
new_customer = [[3, 3]]

# Predict return status
prediction = knn.predict(new_customer)

print("Predicted Product Return:", prediction[0])

# Display the 3 nearest neighbors
distances, indices = knn.kneighbors(new_customer)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Delivery Days={X[idx][0]}, "
        f"Rating={X[idx][1]}, "
        f"Return={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Product Return: Yes
#
# Nearest Neighbors:
# Neighbor 1: Delivery Days=4, Rating=3, Return=Yes, Distance=1.00
# Neighbor 2: Delivery Days=2, Rating=4, Return=No, Distance=1.41
# Neighbor 3: Delivery Days=5, Rating=2, Return=Yes, Distance=2.24

# %%
# 10: Exam Eligibility Prediction

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error


X = [
    [55, 60],
    [65, 70],
    [75, 80],
    [85, 90],
    [95, 95]
]

y = [
    "No",
    "No",
    "Yes",
    "Yes",
    "Yes"
]

# Create KNN model with K = 3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X, y)

# New student data
new_student = [[78, 82]]

# Predict eligibility
prediction = knn.predict(new_student)

print("Predicted Exam Eligibility:", prediction[0])

# Show 3 nearest neighbors
distances, indices = knn.kneighbors(new_student)

print("\nNearest Neighbors:")
for i in range(len(indices[0])):
    idx = indices[0][i]
    print(
        f"Neighbor {i+1}: Attendance={X[idx][0]}, "
        f"Assignment={X[idx][1]}, "
        f"Eligible={y[idx]}, "
        f"Distance={distances[0][i]:.2f}"
    )
# Out:
# Predicted Exam Eligibility: Yes
#
# Nearest Neighbors:
# Neighbor 1: Attendance=75, Assignment=80, Eligible=Yes, Distance=3.61
# Neighbor 2: Attendance=85, Assignment=90, Eligible=Yes, Distance=10.63
# Neighbor 3: Attendance=65, Assignment=70, Eligible=No, Distance=17.69
