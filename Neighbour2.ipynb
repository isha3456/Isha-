# %% [markdown]
# <a href="https://colab.research.google.com/github/isha3456/Isha-/blob/main/Neighbour2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

data={
    'CGPA':[6,7,8,9],
    'Attend':[75,85,95,100],
    'Place':['No','No','Yes','Yes']
}

df=pd.DataFrame(data)
print(df)

x=df.iloc[:,:-1]
y=df.iloc[:,-1]
print(x)
print(y)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train)
print(x_test)
print(y_train)
print(y_test)


model=KNeighborsClassifier(n_neighbors=1)
model.fit(x_train,y_train)
prediction=model.predict(x_test)
print(prediction)

error=accuracy_score(y_test,prediction)
print("Accuracy",error)
# Out:
#    CGPA  Attend Place
# 0     6      75    No
# 1     7      85    No
# 2     8      95   Yes
# 3     9     100   Yes
#    CGPA  Attend
# 0     6      75
# 1     7      85
# 2     8      95
# 3     9     100
# 0     No
# 1     No
# 2    Yes
# 3    Yes
# Name: Place, dtype: object
#    CGPA  Attend
# 3     9     100
# 0     6      75
# 2     8      95
#    CGPA  Attend
# 1     7      85
# 3    Yes
# 0     No
# 2    Yes
# Name: Place, dtype: object
# 1    No
# Name: Place, dtype: object
# ['No']
# Accuracy 1.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

data={
    'Customer':['A','B','C','D','E','F','G'],
    'Age':[20,24,28,32,35,22,30],
    'Monthly Income':[25000,30000,40000,50000,55000,28000,45000],
    'Purchase':['NO','NO','YES','YES','YES','NO','YES']
}

df=pd.DataFrame(data)
print(df)


x=df.drop('Customer', axis=1).iloc[:,:-1]
x=df.iloc[:, 1:-1]
print(x)
print(y)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train)
print(x_test)
print(y_train)
print(y_test)


model=KNeighborsClassifier(n_neighbors=1)
model.fit(x_train,y_train)
prediction=model.predict(x_test)
print(prediction)

error=accuracy_score(y_test,prediction)
print("Accuracy",error)
# Out:
#   Customer  Age  Monthly Income Purchase
# 0        A   20           25000       NO
# 1        B   24           30000       NO
# 2        C   28           40000      YES
# 3        D   32           50000      YES
# 4        E   35           55000      YES
# 5        F   22           28000       NO
# 6        G   30           45000      YES
#    Age  Monthly Income
# 0   20           25000
# 1   24           30000
# 2   28           40000
# 3   32           50000
# 4   35           55000
# 5   22           28000
# 6   30           45000
# 0     NO
# 1     NO
# 2    YES
# 3    YES
# 4    YES
# 5     NO
# 6    YES
# Name: Purchase, dtype: object
#    Age  Monthly Income
# 5   22           28000
# 2   28           40000
# 4   35           55000
# 3   32           50000
# 6   30           45000
#    Age  Monthly Income
# 0   20           25000
# 1   24           30000
# 5     NO
# 2    YES
# 4    YES
# 3    YES
# 6    YES
# Name: Purchase, dtype: object
# 0    NO
# 1    NO
# ...
